# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.cm as cm
import seaborn as sns
import glob
import math

# %%
index = ["DATETIME", "OPEN", "HIGH", "LOW", "CLOSE", "VOLUME", "NUMBER OF TRADES", "WEIGHTED AV. PRICE"]

# %%
path = r'C:\Users\khanf\Documents\PROJECT\AAPL_1HOUR_3yu77g'
all_files = glob.glob(path + "/*.csv")
li = []
# index = ["DATETIME", "OPEN", "HIGH", "LOW", "CLOSE", "VOLUME", "NUMBER OF TRADES", "WEIGHTED AV. PRICE"]
for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=None, names=index)
    li.append(df)

apple = pd.concat(li, axis=0, ignore_index=True, sort=False)

# %%
apple.head()
# Out:
#               DATETIME  OPEN  HIGH   LOW  CLOSE  VOLUME  NUMBER OF TRADES  \
# 0  2004.01.23 09:30:00  3.18  3.22  3.20   3.18   31178              1095
# 1  2004.01.23 10:00:00  3.20  3.25  3.23   3.20   46228              1642
# 2  2004.01.23 11:00:00  3.23  3.23  3.23   3.21   32627              1075
# 3  2004.01.23 12:00:00  3.23  3.24  3.22   3.21   40201              1456
# 4  2004.01.23 13:00:00  3.22  3.23  3.21   3.21   14798               778
#
#    WEIGHTED AV. PRICE
# 0            3.203286
# 1            3.231714
# 2            3.222429
# 3            3.227571
# 4            3.218000

# %%
path = r'C:\Users\khanf\Documents\PROJECT\AMZN_1HOUR_xa44em'
all_files = glob.glob(path + "/*.csv")
li = []
# index = ["DATETIME", "OPEN", "HIGH", "LOW", "CLOSE", "VOLUME", "NUMBER OF TRADES", "WEIGHTED AV. PRICE"]
for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=None, names=index)
    li.append(df)

amzn = pd.concat(li, axis=0, ignore_index=True, sort=False)

# %%
amzn.head()
# Out:
#               DATETIME   OPEN   HIGH    LOW  CLOSE  VOLUME  NUMBER OF TRADES  \
# 0  2004.01.23 09:30:00  57.10  57.10  56.80  56.62    6487              2270
# 1  2004.01.23 10:00:00  56.82  57.40  57.34  56.76   11549              3987
# 2  2004.01.23 11:00:00  57.31  57.34  57.26  56.91    8572              2643
# 3  2004.01.23 12:00:00  57.26  57.61  57.34  57.22    7622              2629
# 4  2004.01.23 13:00:00  57.35  57.60  57.12  57.11    4841              1450
#
#    WEIGHTED AV. PRICE
# 0              56.855
# 1              57.150
# 2              57.136
# 3              57.393
# 4              57.296

# %%
path = r'C:\Users\khanf\Documents\PROJECT\FB_1HOUR_5nzke0'
all_files = glob.glob(path + "/*.csv")
li = []
# index = ["DATETIME", "OPEN", "HIGH", "LOW", "CLOSE", "VOLUME", "NUMBER OF TRADES", "WEIGHTED AV. PRICE"]
for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=None, names=index)
    li.append(df)

fb = pd.concat(li, axis=0, ignore_index=True, sort=False)

# %%
fb.head()
# Out:
#               DATETIME   OPEN   HIGH    LOW  CLOSE   VOLUME  NUMBER OF TRADES  \
# 0  2012.05.18 11:00:00  42.05  45.00  38.86  38.00  2119935            422063
# 1  2012.05.18 12:00:00  38.85  42.00  41.01  38.01   918855            398534
# 2  2012.05.18 13:00:00  41.00  42.00  40.17  40.13   555244            212849
# 3  2012.05.18 14:00:00  40.15  42.00  39.13  38.00   696831            206701
# 4  2012.05.18 15:00:00  39.13  40.25  38.18  38.00  1078805            226303
#
#    WEIGHTED AV. PRICE
# 0              40.464
# 1              40.442
# 2              41.094
# 3              40.131
# 4              38.197

# %%
path = r'C:\Users\khanf\Documents\PROJECT\GOOG_1HOUR_ddt51z'
all_files = glob.glob(path + "/*.csv")
li = []
# index = ["DATETIME", "OPEN", "HIGH", "LOW", "CLOSE", "VOLUME", "NUMBER OF TRADES", "WEIGHTED AV. PRICE"]
for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=None, names=index)
    li.append(df)

google = pd.concat(li, axis=0, ignore_index=True, sort=False)

# %%
google.head()
# Out:
#               DATETIME    OPEN    HIGH     LOW   CLOSE  VOLUME  \
# 0  2014.03.27 09:30:00  566.47  566.47  558.34  551.51       8
# 1  2014.03.27 10:00:00  560.01  561.85  559.79  559.79      12
# 2  2014.03.27 11:00:00  560.33  560.33  551.43  551.43      18
# 3  2014.03.27 12:00:00  551.70  556.64  555.60  551.70       9
# 4  2014.03.27 13:00:00  557.08  560.33  557.49  557.08      13
#
#    NUMBER OF TRADES  WEIGHTED AV. PRICE
# 0                 8          560.765932
# 1                12          560.583425
# 2                17          554.755161
# 3                 9          554.783086
# 4                13          558.598783

# %%
path = r'C:\Users\khanf\Documents\PROJECT\MSFT_1HOUR_t7vfni'
all_files = glob.glob(path + "/*.csv")
li = []
index = ["DATETIME", "OPEN", "HIGH", "LOW", "CLOSE", "VOLUME", "NUMBER OF TRADES", "WEIGHTED AV. PRICE"]
for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=None, names=index)
    li.append(df)

msft = pd.concat(li, axis=0, ignore_index=True, sort=False)

# %%
msft.head()
# Out:
#               DATETIME   OPEN   HIGH    LOW  CLOSE  VOLUME  NUMBER OF TRADES  \
# 0  2004.01.23 09:30:00  28.27  28.62  28.53  28.22  255885             21336
# 1  2004.01.23 10:00:00  28.54  28.76  28.66  28.52  229302             24071
# 2  2004.01.23 11:00:00  28.66  28.70  28.55  28.52  156298             17527
# 3  2004.01.23 12:00:00  28.55  28.59  28.41  28.40  125556             14631
# 4  2004.01.23 13:00:00  28.41  28.61  28.48  28.37  137064             14527
#
#    WEIGHTED AV. PRICE
# 0              28.438
# 1              28.651
# 2              28.613
# 3              28.497
# 4              28.485

# %%
# fig,ax=plt.subplots(2,1,figsize=(20,5))
# plt.subplots_adjust(left=None, bottom=0.1, right=None, top=1.4, wspace=None, hspace=None)
fig = plt.figure(figsize=(20,10))
ax = plt.subplot(111)
date1 = np.linspace(2004, 2019, num = 26600)
date2 = np.linspace(2004, 2019, num = 26208)
date3 = np.linspace(2012, 2019, num = 11602)
date4 = np.linspace(2014, 2019, num = 8367)
date5 = np.linspace(2004, 2019, num = 26208)
ax.plot(date1, apple['CLOSE'], label="Apple")
ax.plot(date2, amzn['CLOSE'], label="Amazon")
ax.plot(date3, fb['CLOSE'], label="Facebook")
ax.plot(date4, google['CLOSE'], label="Google")
ax.plot(date5, msft['CLOSE'], label="Microsoft")
ax.set_title('Closing Price')
ax.legend(loc='upper left')

plt.show()

# %%
fig = plt.figure(figsize=(20,10))
ax = plt.subplot(111)
date1 = np.linspace(2004, 2019, num = 26600)
date2 = np.linspace(2004, 2019, num = 26208)
date3 = np.linspace(2012, 2019, num = 11602)
date4 = np.linspace(2014, 2019, num = 8367)
date5 = np.linspace(2004, 2019, num = 26208)
ax.plot(date1, apple['VOLUME']/1000000, label="Apple")
ax.plot(date2, amzn['VOLUME']/1000000, label="Amazon")
ax.plot(date3, fb['VOLUME']/1000000, label="Facebook")
ax.plot(date4, google['VOLUME']/1000000, label="Google")
ax.plot(date5, msft['VOLUME']/1000000, label="Microsoft")
ax.legend(loc='upper left')
ax.set_title('Volume of Stocks traded (1e7)')

plt.show()
